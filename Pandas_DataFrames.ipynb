# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/productivity-statistics-1978-2024.csv")

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value STATUS  \
# 0     PRDA.S1CAAZI  1978.03      1000.0  FINAL
# 1     PRDA.S1CAAZI  1979.03       947.0  FINAL
# 2     PRDA.S1CAAZI  1980.03      1054.0  FINAL
# 3     PRDA.S1CAAZI  1981.03      1167.0  FINAL
# 4     PRDA.S1CAAZI  1982.03      1144.0  FINAL
#
#                                               Group  \
# 0  Productivity Indexes - Industry Level (ANZSIC06)
# 1  Productivity Indexes - Industry Level (ANZSIC06)
# 2  Productivity Indexes - Industry Level (ANZSIC06)
# 3  Productivity Indexes - Industry Level (ANZSIC06)
# 4  Productivity Indexes - Industry Level (ANZSIC06)
#
#                          Subject Series_title_1  \
# 0  Productivity Statistics - PRD        Capital
# 1  Productivity Statistics - PRD        Capital
# 2  Productivity Statistics - PRD        Capital
# 3  Productivity Statistics - PRD        Capital
# 4  Productivity Statistics - PRD        Capital
#
# ...

# %%
df.shape
# Out:
# (15580, 13)

# %%
df_rows=df.shape[0] #find number of rows in a dataset
df_rows
# Out:
# 15580

# %%
df.describe(include="all")
# Out:
#        Series_reference       Period    Data_value STATUS  \
# count             15580  15580.00000  15580.000000  15580
# unique              394          NaN           NaN      3
# top        PRDA.S1CAAZI          NaN           NaN  FINAL
# freq                 47          NaN           NaN  11736
# mean                NaN   2003.74534   1088.267985    NaN
# std                 NaN     12.88929   3520.099597    NaN
# min                 NaN   1978.03000    -28.900000    NaN
# 25%                 NaN   1994.03000      1.600000    NaN
# 50%                 NaN   2005.03000    591.000000    NaN
# 75%                 NaN   2015.03000   1328.000000    NaN
# max                 NaN   2024.03000  68537.000000    NaN
#
#                                                     Group  \
# count                                               15580
# unique                                                  8
# top     Productivity Input Series - Industry Level (AN...
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value STATUS  \
# 0     PRDA.S1CAAZI  1978.03      1000.0  FINAL
# 1     PRDA.S1CAAZI  1979.03       947.0  FINAL
# 2     PRDA.S1CAAZI  1980.03      1054.0  FINAL
# 3     PRDA.S1CAAZI  1981.03      1167.0  FINAL
# 4     PRDA.S1CAAZI  1982.03      1144.0  FINAL
#
#                                               Group  \
# 0  Productivity Indexes - Industry Level (ANZSIC06)
# 1  Productivity Indexes - Industry Level (ANZSIC06)
# 2  Productivity Indexes - Industry Level (ANZSIC06)
# 3  Productivity Indexes - Industry Level (ANZSIC06)
# 4  Productivity Indexes - Industry Level (ANZSIC06)
#
#                          Subject Series_title_1  \
# 0  Productivity Statistics - PRD        Capital
# 1  Productivity Statistics - PRD        Capital
# 2  Productivity Statistics - PRD        Capital
# 3  Productivity Statistics - PRD        Capital
# 4  Productivity Statistics - PRD        Capital
#
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value       STATUS  \
# 15575     PRDA.S4LMSZP  2020.03         0.5        FINAL
# 15576     PRDA.S4LMSZP  2021.03        -0.5        FINAL
# 15577     PRDA.S4LMSZP  2022.03         2.0      REVISED
# 15578     PRDA.S4LMSZP  2023.03         2.0      REVISED
# 15579     PRDA.S4LMSZP  2024.03         0.7  PROVISIONAL
#
#                                            Group  \
# 15575  Productivity Growth Accounting (ANZSIC06)
# 15576  Productivity Growth Accounting (ANZSIC06)
# 15577  Productivity Growth Accounting (ANZSIC06)
# 15578  Productivity Growth Accounting (ANZSIC06)
# 15579  Productivity Growth Accounting (ANZSIC06)
#
#                              Subject  \
# 15575  Productivity Statistics - PRD
# 15576  Productivity Statistics - PRD
# 15577  Productivity Statistics - PRD
# 15578  Productivity Statistics - PRD
# 15579  Productivity Statistics - PRD
#
#                                           Series_title_1 Series_title_2  \
# ...

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value              0
# STATUS                  0
# Group                   0
# Subject                 0
# Series_title_1          0
# Series_title_2        597
# Series_title_3        597
# Series_title_4      15580
# Series_title_5      15580
# UNITS                   0
# MAGNITUDE               0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Series_reference   Period  Data_value       STATUS  \
# 0         PRDA.S1CAAZI  1978.03      1000.0        FINAL
# 1         PRDA.S1CAAZI  1979.03       947.0        FINAL
# 2         PRDA.S1CAAZI  1980.03      1054.0        FINAL
# 3         PRDA.S1CAAZI  1981.03      1167.0        FINAL
# 4         PRDA.S1CAAZI  1982.03      1144.0        FINAL
# ...                ...      ...         ...          ...
# 15575     PRDA.S4LMSZP  2020.03         0.5        FINAL
# 15576     PRDA.S4LMSZP  2021.03        -0.5        FINAL
# 15577     PRDA.S4LMSZP  2022.03         2.0      REVISED
# 15578     PRDA.S4LMSZP  2023.03         2.0      REVISED
# 15579     PRDA.S4LMSZP  2024.03         0.7  PROVISIONAL
#
#                                                   Group  \
# 0      Productivity Indexes - Industry Level (ANZSIC06)
# 1      Productivity Indexes - Industry Level (ANZSIC06)
# 2      Productivity Indexes - Industry Level (ANZSIC06)
# ...
